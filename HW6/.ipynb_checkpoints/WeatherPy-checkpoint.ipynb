# %% [markdown]
# # WeatherPy

# %% [markdown]
# ### Analysis

# %%
import openweathermapy.core as owm
from citipy import citipy
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import imp
api = imp.load_source('api', '/Users/thomas/Desktop/Boot Camp/Keys/api.py')
from api import owmkey

# %%
cities = []
for x in range(1500):
    lat=np.random.uniform(-90,90)
    lng=np.random.uniform(-180,180)
    city = citipy.nearest_city(lat,lng)
    cities.append(city.city_name)
names = pd.unique(cities)

# %%
settings = {"units": "imperial", "APPID": owmkey}


for name in names:
    try:
        forecast = owm.get_current(name, **settings)
        print(forecast['name'])
        
    except HTTPError:
        print('Not Found')
# Out:
# Cidreira
# Albany
# Mataura
# Doctor Arroyo
# Ushuaia
# Hammerfest
# Marawi
# Jiuquan
# Bathsheba
# Hermanus
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-30-05af5dc157e0> in <module>()
#       5     try:
# ----> 6         forecast = owm.get_current(name, **settings)
#       7         print(forecast['name'])
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/openweathermapy/core.py in get_current(city, **params)
#     154 	"""
# --> 155         data = wrap_get("weather")(city, **params)
#     156         return DataPoint(data)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/openweathermapy/core.py in call(loc, **params)
#      98                         params.update(settings)
# ---> 99                 data = get(url, **params)
#     100                 if converter:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/openweathermapy/core.py in get(url, **params)
#      61         """Return data as (nested) dictionary for ``url`` request."""
# ---> 62         data = utils.get_url_response(url, **params)
#      63         # Decoding: Python3 compatibility
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/openweathermapy/utils.py in get_url_response(url, **params)
#      30                 url = url+"?"+urlencode(params)
# ---> 31         response = urlopen(url)
#      32         data = response.read()
#
# ~/anaconda3/envs/PythonData/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# ~/anaconda3/envs/PythonData/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#
# ~/anaconda3/envs/PythonData/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#
# ~/anaconda3/envs/PythonData/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#
# ~/anaconda3/envs/PythonData/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#
# HTTPError: HTTP Error 404: Not Found
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-05af5dc157e0> in <module>()
#       7         print(forecast['name'])
#       8
# ----> 9     except HTTPError:
#      10         print('Not Found')
#      11
#
# NameError: name 'HTTPError' is not defined

# %%
# Out:
# punta arenas
# hirara
# hunza
# mackenzie
# urengoy
# punta alta
# lagos
# hilo
# bluff
# capari
# illoqqortoormiut
# kapaa
# hermanus
# longyearbyen
# rikitea
# nizhneyansk
# severo-kurilsk
# omboue
# atuona
# new norfolk
# abha
# tuktoyaktuk
# kropotkin
# samarai
# norman wells
# graaff-reinet
# cayenne
# samusu
# ushuaia
# jamestown
# alofi
# clyde river
# georgetown
# fray bentos
# puerto carreno
# taolanaro
# broome
# fairbanks
# saskylakh
# bethel
# katsuura
# kruisfontein
# puerto ayora
# caravelas
# ahipara
# mataura
# butaritari
# mujiayingzi
# albany
# tabiauea
# villa maria
# kitui
# faranah
# laguna
# tigil
# marcona
# sept-iles
# tiksi
# busselton
# vaini
# mahebourg
# wuwei
# rajapalaiyam
# lebu
# port elizabeth
# fujioka
# paracuru
# tasiilaq
# guapore
# yellowknife
# reitz
# zaozerne
# castro
# hobyo
# knysna
# bathsheba
# thompson
# luderitz
# umm lajj
# demba
# homer
# shimoda
# qaanaaq
# tursunzoda
# trudarmeyskiy
# goya
# port alfred
# kodiak
# kodala
# inhambane
# saint pete beach
# fare
# pucallpa
# bredasdorp
# rawson
# buala
# serov
# kaitangata
# chuy
